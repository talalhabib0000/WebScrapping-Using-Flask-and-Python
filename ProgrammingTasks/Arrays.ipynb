# %%
import random

# %%
array = [random.randint(0,100) for x in range (1000)]

# %%
array[:10]
# Out:
# [9, 31, 76, 95, 50, 67, 9, 61, 98, 40]

# %% [markdown]
# # Find array count

# %%
size = len(array)
print(size)
# Out:
# 100

# %% [markdown]
# # Find sum of even and odd values

# %% [markdown]
# Lst[ Initial : End : IndexJump ]

# %%
array = [random.randint(0,100) for x in range (1000)]
result=0

for i in array:
    if i%2==0: 
        print(f"Even number: {i}")
        result +=i
        print("the total of even number is: ",result)
# Out:
# Even number: 40
# the total of even number is:  40
# Even number: 10
# the total of even number is:  50
# Even number: 68
# the total of even number is:  118
# Even number: 24
# the total of even number is:  142
# Even number: 20
# the total of even number is:  162
# Even number: 34
# the total of even number is:  196
# Even number: 0
# the total of even number is:  196
# Even number: 50
# the total of even number is:  246
# Even number: 72
# the total of even number is:  318
# Even number: 94
# the total of even number is:  412
# Even number: 70
# the total of even number is:  482
# Even number: 86
# the total of even number is:  568
# Even number: 64
# the total of even number is:  632
# Even number: 42
# the total of even number is:  674
# Even number: 78
# the total of even number is:  752
# Even number: 0
# the total of even number is:  752
# Even number: 46
# the total of even number is:  798
# Even number: 66
# the total of even number is:  864
# Even number: 26
# ...

# %% [markdown]
# # Find values which are in both arrays

# %%
array1 = [random.randint(0,100) for x in range (100)]
array2 = [random.randint(0,100) for x in range (100)]

# %% [markdown]
# The and is a type of Logical AND that returns in a True form whenever both the operands are also true

# %%
# set(array1) & set(array2)
set(array1).intersection(array2)

# %% [markdown]
# # Take square of the items in array

# %%
import numpy as np
answer=np.sqrt(array)
print("The square root of array is :",answer)
# from math import sqrt
# answer=sqrt(array)
# print("The square root of array is :",answer)
# Out:
# The square root of array is : [ 2.44948974  9.64365076  6.164414    6.244998    3.74165739  6.55743852
#   6.55743852  7.87400787  9.59166305  9.69535971  1.          6.4807407
#   8.18535277  6.63324958  8.42614977  5.19615242  9.94987437  9.59166305
#   5.          6.63324958  4.35889894  0.          6.70820393  9.16515139
#   2.23606798  3.46410162  2.82842712  7.21110255  7.87400787  5.29150262
#   6.92820323  6.70820393  7.68114575  1.73205081  6.244998    2.64575131
#   8.24621125  6.08276253  3.87298335  4.24264069  7.81024968  1.41421356
#   7.54983444  6.55743852  3.16227766  5.          5.91607978  8.88819442
#   3.46410162  8.60232527  2.44948974  2.82842712  8.          9.05538514
#   9.74679434  6.8556546   6.63324958  8.54400375  7.07106781  2.82842712
#   6.8556546   5.56776436  8.60232527  8.30662386  7.          9.8488578
#   7.54983444  6.244998    6.70820393  9.11043358  3.74165739  5.91607978
# ...

# %% [markdown]
# # print items greater then 50

# %%
for i in array:
    if array[i]>50:
        print("The values greater than 50 are:",array[i])

# %% [markdown]
# # print percentage if items which are less then 30

# %%
size=len(array)
array1=[]
for i in array:
    if array[i]<=30: 
        array1.append(array[i])

# %%
array1
length=len(array1)
percentage=((length/size)*100)
print("Total integers less than 30 are:" ,percentage)
# Out:
# Total integers less than 30 are: 37.3
